# %% [markdown]
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from IPython.display import display, HTML

# %%
data=pd.read_csv("dataset.csv")

# %%
data.shape
# Out:
# (266, 68)

# %%
data.head(10)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 7                   Arab World          ARB  Population, total    SP.POP.TOTL
# 8         United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 9                    Argentina          ARG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# 5    1608800.0    1659800.0    1711319.0    1762621.0    1814135.0
# 6       9443.0      10216.0      11014.0      11839.0      12690.0
# 7   93359407.0   95760348.0   98268683.0  100892507.0  103618568.0
# 8     133426.0     140984.0     148877.0     157006.0     165305.0
# 9   20349744.0   20680653.0   21020359.0   21364017.0   21708487.0
#
#           1965  ...         2014         2015         2016         2017  \
# 0      58782.0  ...     103594.0     104257.0     104874.0     105439.0
# 1  149742351.0  ...  583651101.0  600008424.0  616377605.0  632746570.0
# 2    9565147.0  ...   32716210.0   33753499.0   34636207.0   35643418.0
# 3  108336203.0  ...  397855507.0  408690375.0  419778384.0  431138704.0
# 4    5736582.0  ...   27128337.0   28127721.0   29154746.0   30208628.0
# 5    1864791.0  ...    2889104.0    2880703.0    2876101.0    2873457.0
# 6      13563.0  ...      71621.0      71746.0      72540.0      73837.0
# 7  106444103.0  ...  397922915.0  406501999.0  415077960.0  423664839.0
# 8     173797.0  ...    8835951.0    8916899.0    8994263.0    9068296.0
# 9   22053661.0  ...   42669500.0   43131966.0   43590368.0   44044811.0
#
#           2018         2019         2020         2021         2022  \
# 0     105962.0     106442.0     106585.0     106537.0     106445.0
# 1  649757148.0  667242986.0  685112979.0  702977106.0  720859132.0
# 2   36686784.0   37769499.0   38972230.0   40099462.0   41128771.0
# 3  442646825.0  454306063.0  466189102.0  478185907.0  490330870.0
# 4   31273533.0   32353588.0   33428486.0   34503774.0   35588987.0
# 5    2866376.0    2854191.0    2837849.0    2811666.0    2777689.0
# 6      75013.0      76343.0      77700.0      79034.0      79824.0
# 7  432545676.0  441467739.0  449228296.0  456520777.0  464684914.0
# 8    9140169.0    9211657.0    9287289.0    9365145.0    9441129.0
# 9   44494502.0   44938712.0   45376763.0   45808747.0   46234830.0
#
#           2023
# 0     106277.0
# 1  739108306.0
# 2   42239854.0
# 3  502789511.0
# 4   36684202.0
# 5    2745972.0
# 6      80088.0
# 7  473272080.0
# 8    9516871.0
# 9   46654581.0
#
# [10 rows x 68 columns]

# %%
data.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# 2023              1
# Length: 68, dtype: int64

# %%
data.dropna(axis=1, thresh=df.shape[0]*0.5)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# 1      SP.POP.TOTL  130692579.0  134169237.0  137835590.0  141630546.0
# 2      SP.POP.TOTL    8622466.0    8790140.0    8969047.0    9157465.0
# 3      SP.POP.TOTL   97256290.0   99314028.0  101445032.0  103667517.0
# 4      SP.POP.TOTL    5357195.0    5441333.0    5521400.0    5599827.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     990150.0    1014211.0    1038618.0    1063175.0
# 262    SP.POP.TOTL    5542459.0    5646668.0    5753386.0    5860197.0
# 263    SP.POP.TOTL   16520441.0   16989464.0   17503133.0   18042215.0
# 264    SP.POP.TOTL    3119430.0    3219451.0    3323427.0    3431381.0
# 265    SP.POP.TOTL    3806310.0    3925952.0    4049778.0    4177931.0
#
#             1964         1965  ...         2014         2015         2016  \
# 0        58178.0      58782.0  ...     103594.0     104257.0     104874.0
# 1    145605995.0  149742351.0  ...  583651101.0  600008424.0  616377605.0
# 2      9355514.0    9565147.0  ...   32716210.0   33753499.0   34636207.0
# 3    105959979.0  108336203.0  ...  397855507.0  408690375.0  419778384.0
# 4      5673199.0    5736582.0  ...   27128337.0   28127721.0   29154746.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1087700.0    1111812.0  ...    1812771.0    1788196.0    1777557.0
# 262    5973803.0    6097298.0  ...   27753304.0   28516545.0   29274002.0
# 263   18603097.0   19187194.0  ...   54729551.0   55876504.0   56422274.0
# 264    3542764.0    3658024.0  ...   15737793.0   16248230.0   16767761.0
# 265    4310332.0    4447149.0  ...   13855753.0   14154937.0   14452704.0
#
#             2017         2018         2019         2020         2021  \
# 0       105439.0     105962.0     106442.0     106585.0     106537.0
# 1    632746570.0  649757148.0  667242986.0  685112979.0  702977106.0
# 2     35643418.0   36686784.0   37769499.0   38972230.0   40099462.0
# 3    431138704.0  442646825.0  454306063.0  466189102.0  478185907.0
# 4     30208628.0   31273533.0   32353588.0   33428486.0   34503774.0
# ..           ...          ...          ...          ...          ...
# 261    1791003.0    1797085.0    1788878.0    1790133.0    1786038.0
# 262   30034389.0   30790513.0   31546691.0   32284046.0   32981641.0
# 263   56641209.0   57339635.0   58087055.0   58801927.0   59392255.0
# 264   17298054.0   17835893.0   18380477.0   18927715.0   19473125.0
# 265   14751101.0   15052184.0   15354608.0   15669666.0   15993524.0
#
#             2022         2023
# 0       106445.0     106277.0
# 1    720859132.0  739108306.0
# 2     41128771.0   42239854.0
# 3    490330870.0  502789511.0
# 4     35588987.0   36684202.0
# ..           ...          ...
# 261    1768086.0    1756374.0
# 262   33696614.0   34449825.0
# 263   59893885.0   60414495.0
# 264   20017675.0   20569737.0
# 265   16320537.0   16665409.0
#
# [266 rows x 68 columns]

# %%
data=df

# %%
df.shape
# Out:
# (266, 68)

# %%
df = df.drop_duplicates()
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# 1      SP.POP.TOTL  130692579.0  134169237.0  137835590.0  141630546.0
# 2      SP.POP.TOTL    8622466.0    8790140.0    8969047.0    9157465.0
# 3      SP.POP.TOTL   97256290.0   99314028.0  101445032.0  103667517.0
# 4      SP.POP.TOTL    5357195.0    5441333.0    5521400.0    5599827.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     990150.0    1014211.0    1038618.0    1063175.0
# 262    SP.POP.TOTL    5542459.0    5646668.0    5753386.0    5860197.0
# 263    SP.POP.TOTL   16520441.0   16989464.0   17503133.0   18042215.0
# 264    SP.POP.TOTL    3119430.0    3219451.0    3323427.0    3431381.0
# 265    SP.POP.TOTL    3806310.0    3925952.0    4049778.0    4177931.0
#
#             1964         1965  ...         2014         2015         2016  \
# 0        58178.0      58782.0  ...     103594.0     104257.0     104874.0
# 1    145605995.0  149742351.0  ...  583651101.0  600008424.0  616377605.0
# 2      9355514.0    9565147.0  ...   32716210.0   33753499.0   34636207.0
# 3    105959979.0  108336203.0  ...  397855507.0  408690375.0  419778384.0
# 4      5673199.0    5736582.0  ...   27128337.0   28127721.0   29154746.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1087700.0    1111812.0  ...    1812771.0    1788196.0    1777557.0
# 262    5973803.0    6097298.0  ...   27753304.0   28516545.0   29274002.0
# 263   18603097.0   19187194.0  ...   54729551.0   55876504.0   56422274.0
# 264    3542764.0    3658024.0  ...   15737793.0   16248230.0   16767761.0
# 265    4310332.0    4447149.0  ...   13855753.0   14154937.0   14452704.0
#
#             2017         2018         2019         2020         2021  \
# 0       105439.0     105962.0     106442.0     106585.0     106537.0
# 1    632746570.0  649757148.0  667242986.0  685112979.0  702977106.0
# 2     35643418.0   36686784.0   37769499.0   38972230.0   40099462.0
# 3    431138704.0  442646825.0  454306063.0  466189102.0  478185907.0
# 4     30208628.0   31273533.0   32353588.0   33428486.0   34503774.0
# ..           ...          ...          ...          ...          ...
# 261    1791003.0    1797085.0    1788878.0    1790133.0    1786038.0
# 262   30034389.0   30790513.0   31546691.0   32284046.0   32981641.0
# 263   56641209.0   57339635.0   58087055.0   58801927.0   59392255.0
# 264   17298054.0   17835893.0   18380477.0   18927715.0   19473125.0
# 265   14751101.0   15052184.0   15354608.0   15669666.0   15993524.0
#
#             2022         2023
# 0       106445.0     106277.0
# 1    720859132.0  739108306.0
# 2     41128771.0   42239854.0
# 3    490330870.0  502789511.0
# 4     35588987.0   36684202.0
# ..           ...          ...
# 261    1768086.0    1756374.0
# 262   33696614.0   34449825.0
# 263   59893885.0   60414495.0
# 264   20017675.0   20569737.0
# 265   16320537.0   16665409.0
#
# [266 rows x 68 columns]

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# Length: 68, dtype: int64

# %%
df = df.drop(['Country Code','Indicator Name','Indicator Code'], axis=1)

# %%
df.head(5)
# Out:
#                                     1960         1961         1962  \
# Country Name
# Aruba                            54608.0      55811.0      56682.0
# Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# Afghanistan                    8622466.0    8790140.0    8969047.0
# Africa Western and Central    97256290.0   99314028.0  101445032.0
# Angola                         5357195.0    5441333.0    5521400.0
#
#                                     1963         1964         1965  \
# Country Name
# Aruba                            57475.0      58178.0      58782.0
# Africa Eastern and Southern  141630546.0  145605995.0  149742351.0
# Afghanistan                    9157465.0    9355514.0    9565147.0
# Africa Western and Central   103667517.0  105959979.0  108336203.0
# Angola                         5599827.0    5673199.0    5736582.0
#
#                                     1966         1967         1968  \
# Country Name
# Aruba                            59291.0      59522.0      59471.0
# Africa Eastern and Southern  153955516.0  158313235.0  162875171.0
# Afghanistan                    9783147.0   10010030.0   10247780.0
# Africa Western and Central   110798486.0  113319950.0  115921723.0
# Angola                         5787044.0    5827503.0    5868203.0
#
#                                     1969  ...         2014         2015  \
# Country Name                              ...
# Aruba                            59330.0  ...     103594.0     104257.0
# Africa Eastern and Southern  167596160.0  ...  583651101.0  600008424.0
# Afghanistan                   10494489.0  ...   32716210.0   33753499.0
# Africa Western and Central   118615741.0  ...  397855507.0  408690375.0
# Angola                         5928386.0  ...   27128337.0   28127721.0
#
#                                     2016         2017         2018  \
# Country Name
# Aruba                           104874.0     105439.0     105962.0
# Africa Eastern and Southern  616377605.0  632746570.0  649757148.0
# Afghanistan                   34636207.0   35643418.0   36686784.0
# Africa Western and Central   419778384.0  431138704.0  442646825.0
# Angola                        29154746.0   30208628.0   31273533.0
#
#                                     2019         2020         2021  \
# Country Name
# Aruba                           106442.0     106585.0     106537.0
# Africa Eastern and Southern  667242986.0  685112979.0  702977106.0
# Afghanistan                   37769499.0   38972230.0   40099462.0
# Africa Western and Central   454306063.0  466189102.0  478185907.0
# Angola                        32353588.0   33428486.0   34503774.0
#
#                                     2022         2023
# Country Name
# Aruba                           106445.0     106277.0
# Africa Eastern and Southern  720859132.0  739108306.0
# Afghanistan                   41128771.0   42239854.0
# Africa Western and Central   490330870.0  502789511.0
# Angola                        35588987.0   36684202.0
#
# [5 rows x 64 columns]

# %%
df1=df.copy()
def format_numbers(number):
    if number >= 1e6:
        return f"{number/1e6:.1f}M"
    elif number >= 1e3:
        return f"{number/1e3:.1f}k"
    else:
        return str(number)
for column in df1.select_dtypes(include='number').columns:
    df1[column] = df1[column].apply(format_numbers)

# %%
df1
# Out:
#                                1960    1961    1962    1963    1964    1965  \
# Country Name
# Aruba                         54.6k   55.8k   56.7k   57.5k   58.2k   58.8k
# Africa Eastern and Southern  130.7M  134.2M  137.8M  141.6M  145.6M  149.7M
# Afghanistan                    8.6M    8.8M    9.0M    9.2M    9.4M    9.6M
# Africa Western and Central    97.3M   99.3M  101.4M  103.7M  106.0M  108.3M
# Angola                         5.4M    5.4M    5.5M    5.6M    5.7M    5.7M
# ...                             ...     ...     ...     ...     ...     ...
# Kosovo                       990.1k    1.0M    1.0M    1.1M    1.1M    1.1M
# Yemen, Rep.                    5.5M    5.6M    5.8M    5.9M    6.0M    6.1M
# South Africa                  16.5M   17.0M   17.5M   18.0M   18.6M   19.2M
# Zambia                         3.1M    3.2M    3.3M    3.4M    3.5M    3.7M
# Zimbabwe                       3.8M    3.9M    4.0M    4.2M    4.3M    4.4M
#
#                                1966    1967    1968    1969  ...    2014  \
# Country Name                                                 ...
# Aruba                         59.3k   59.5k   59.5k   59.3k  ...  103.6k
# Africa Eastern and Southern  154.0M  158.3M  162.9M  167.6M  ...  583.7M
# Afghanistan                    9.8M   10.0M   10.2M   10.5M  ...   32.7M
# Africa Western and Central   110.8M  113.3M  115.9M  118.6M  ...  397.9M
# Angola                         5.8M    5.8M    5.9M    5.9M  ...   27.1M
# ...                             ...     ...     ...     ...  ...     ...
# Kosovo                         1.1M    1.2M    1.2M    1.2M  ...    1.8M
# Yemen, Rep.                    6.2M    6.4M    6.5M    6.7M  ...   27.8M
# South Africa                  19.8M   20.4M   21.1M   21.7M  ...   54.7M
# Zambia                         3.8M    3.9M    4.0M    4.2M  ...   15.7M
# Zimbabwe                       4.6M    4.7M    4.9M    5.0M  ...   13.9M
#
#                                2015    2016    2017    2018    2019    2020  \
# Country Name
# Aruba                        104.3k  104.9k  105.4k  106.0k  106.4k  106.6k
# Africa Eastern and Southern  600.0M  616.4M  632.7M  649.8M  667.2M  685.1M
# Afghanistan                   33.8M   34.6M   35.6M   36.7M   37.8M   39.0M
# Africa Western and Central   408.7M  419.8M  431.1M  442.6M  454.3M  466.2M
# Angola                        28.1M   29.2M   30.2M   31.3M   32.4M   33.4M
# ...                             ...     ...     ...     ...     ...     ...
# Kosovo                         1.8M    1.8M    1.8M    1.8M    1.8M    1.8M
# Yemen, Rep.                   28.5M   29.3M   30.0M   30.8M   31.5M   32.3M
# South Africa                  55.9M   56.4M   56.6M   57.3M   58.1M   58.8M
# Zambia                        16.2M   16.8M   17.3M   17.8M   18.4M   18.9M
# Zimbabwe                      14.2M   14.5M   14.8M   15.1M   15.4M   15.7M
#
#                                2021    2022    2023
# Country Name
# Aruba                        106.5k  106.4k  106.3k
# Africa Eastern and Southern  703.0M  720.9M  739.1M
# Afghanistan                   40.1M   41.1M   42.2M
# Africa Western and Central   478.2M  490.3M  502.8M
# Angola                        34.5M   35.6M   36.7M
# ...                             ...     ...     ...
# Kosovo                         1.8M    1.8M    1.8M
# Yemen, Rep.                   33.0M   33.7M   34.4M
# South Africa                  59.4M   59.9M   60.4M
# Zambia                        19.5M   20.0M   20.6M
# Zimbabwe                      16.0M   16.3M   16.7M
#
# [266 rows x 64 columns]

# %%
#total = df['Total':].transpose()
total = df.loc[:, '1960':'2023']

# %%
figsize = (12, 6)
plt.figure(figsize=figsize)
plt.grid(True, linestyle='--', linewidth=0.5, color='gray',axis='y')
plt.plot(total,linewidth=4)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.xlabel('years from 1960 t0 2023',fontname='Arial', fontsize=18, color='red')
plt.xticks(rotation=90)
plt.ylabel('Population in Millions',fontname='Arial', fontsize=18, color='red')
plt.title('Total Poulation every year',fontname='Arial', fontsize=18, color='red')
plt.show()

# %%
Afghanistan = df.loc['Afghanistan',:].transpose()
Afghanistan=Afghanistan.reset_index()
India = df.loc['India',:].transpose()
India=India.reset_index()
Arab_World = df.loc['Arab World',:].transpose()
Arab_World=Arab_World.reset_index()
Arab_World
Middle = df.loc['Middle East & North Africa',:].transpose()
Middle=Middle.reset_index()
Egypt=df.loc['Egypt, Arab Rep.',:].transpose()
Egypt=Egypt.reset_index()
Middle
# Out:
#    index  Middle East & North Africa
# 0   1960                 104958259.0
# 1   1961                 107670788.0
# 2   1962                 110538003.0
# 3   1963                 113518054.0
# 4   1964                 116624655.0
# ..   ...                         ...
# 59  2019                 473201775.0
# 60  2020                 479966649.0
# 61  2021                 486174763.0
# 62  2022                 493279469.0
# 63  2023                 500787313.0
#
# [64 rows x 2 columns]

# %%
figsize = (12, 6)
plt.figure(figsize=figsize)

plt.bar(India['index'],India['India'],color='blue',label='India')
plt.bar(Arab_World['index'],Arab_World['Arab World'],color='green',label='Arab_World')
plt.bar(Afghanistan['index'], Afghanistan['Afghanistan'],color='red',label='Afghanistan')
plt.grid(True, linestyle='--', linewidth=0.5, color='gray',axis='y')
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.xlabel('years from 1960 t0 2023', fontsize=18, color='red')
plt.xticks(rotation=90)
plt.ylabel('Population in Millions', fontsize=18, color='red')
plt.title('Total Poulation every year', fontsize=18, color='red')
plt.legend(title='Population by Region', loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
cols = ['1960', '1961', '1962', '1963', '1964', '1965', '1966',
       '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
       '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
       '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000','2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019', '2020', '2021', '2022']
# Aggregate all data into a single histogram
all_data = df[cols].values.flatten()  # Flatten DataFrame into a single array
plt.figure(figsize=(10, 6))
plt.hist(all_data, color='#8C564B', bins=20)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Distribution of All Data Over Years')
plt.show()

# %%
for i in cols:
        fig = plt.figure(figsize=(10, 6))
        plt.hist(df[i],color='#9467BD',bins=10)
        plt.xlabel(i)
        plt.show()
